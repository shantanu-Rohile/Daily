# %%
# 1.python syntax

print("jvm : module - Python")
# Out:
# jvm : module - Python

# %%
# 2.python comments

# comment is line of code neglected by interpreter

# %%
# 3.python variable

name = "shantnau rohile"
print(name)
# Out:
# shantnau rohile

# %%
# 4.python datatype

print(type(5))
print(type(name))
print(type(True))
print(type([1]))
print(type({1}))
print(type((4,5)))
print(type({"name":"rohile"}))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'set'>
# <class 'tuple'>
# <class 'dict'>

# %%
# 5.python numbers

x= 10
y = 10.0
z = 1j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# 6.python strings

var = "string of strings"

print(var[2:5])
print(var.upper())

name = "Shantanu Rohile"
print(name)
# Out:
# rin
# STRING OF STRINGS
# Shantanu Rohile

# %%
# 7.python booleans

print(10 > 9)

print(10 == 9)

print(bool("Hello"))

print(bool(0))
# Out:
# True
# False
# True
# False

# %%
# 8.python operators

a =10

b = 20

print(b%a)

print(a//b)

print(a**2)

a += 10

print(a)
# Out:
# 0
# 0
# 100
# 20

# %%
# 9.python list

colors = ["red", "green", "blue"]

print(colors[0])

colors[1] = "yellow"


colors.append("purple")


colors.remove("red")

print(colors)
# Out:
# red
# ['yellow', 'blue', 'purple']

# %%
# 10.python tuple.

fruits =("apple", "banana", "cherry" )
print(fruits[1])
print(len(fruits))
a = fruits[0]
b = fruits[1]
c = fruits[2]
print(b)
# Out:
# banana
# 3
# banana
