# %%
# 1.python classes/objects

class Persson:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Persson("Shantanu",22)

print(p1.age)
# Out:
# 22

# %%
# 2.python inheritance

class Animal:
    def __init__(self,name):
        self.name = name
    def speak(self):
        print(f"name is : {self.name}")

class Dog(Animal):
    pass

d1 = Dog("Rex")

d1.speak()
# Out:
# name is : Rex

# %%
# 3.python iterators
my_list = ["Apple","Orange","Berries"]

iters = iter(my_list)

print(next(iters))
print(next(iters))
print(next(iters))
# Out:
# Apple
# Orange
# Berries

# %%
# 4.python polymorphism.

# Inside the editor, complete the following steps:
# Create a class Cat with a method sound that prints "Meow"
# Create a class Fox with a method sound that prints "Wa-pa-pa-pa-pa-pow!"
# Create objects c1 = Cat() and f1 = Fox()
# Call sound() on both objects


class Cat:
    def sound(self):
        print("Meow")

class Fox:
    def sound(self):
        print("Wa-pa-pa-pa-pa-pow!")

c1 = Cat()

f1 = Fox()

c1.sound()

f1.sound()
# Out:
# Meow
# Wa-pa-pa-pa-pa-pow!

# %%
# 5.python modules.

import platform

print(platform.system())
# Out:
# Windows

# %% [markdown]
# # 6.What is Pandas in Python?
#
# - Pandas is a open-source liabrary in python used to access, analyis and clean on the said data

# %% [markdown]
# # 7.Mention the different types of Data Structures in Pandas?
#
# 1. List
#
# 2. Dictionary
#
# 3. Tuple
#
# 4. Set
#
# 5. frozenset

# %% [markdown]
# # 8. What are the significant features of the pandas Library?
#
# 1. Using multi dimensional arrays
#
# 2. reading files of various types
#
# 3. cleaning data
#
# 4. Analysing the data

# %% [markdown]
# # 9. Define Series in Pandas?
#
# - A Pandas Series is a one-dimensional labeled array capable of holding data of any type, including integers, strings, floating-point numbers, and Python objects.

# %% [markdown]
# # 10. Define DataFrame in Pandas?
#
# - Is a two-dimensional. mutable data structure with rows and columns

# %% [markdown]
# # 11. What are the different ways in which a series can be created?
#
# 1. Empty Series
#
# 2. List Series
#
# 3. npmy array
#
# 3. Dictionary Series
