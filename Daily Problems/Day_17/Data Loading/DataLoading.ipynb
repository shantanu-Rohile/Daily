# %%
import pandas as pd
import pathlib

# %%
path = pathlib.Path(r'F:\Daily\Daily Problems\Day_17\Data Trasnformation\transoformed.csv')
path.exists()
# Out:
# True

# %%
import sqlite3

# %%
# data validation
df = pd.read_csv(path)
df.info()
df.isnull().sum()
df.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        6 non-null      int64
#  1   index                             6 non-null      int64
#  2   RANK                              6 non-null      int64
#  3   PEAK                              6 non-null      int64
#  4   ALL_TIME_PEAK                     6 non-null      int64
#  5   ACTUAL_GROSS                      6 non-null      int64
#  6   ADJUSTED_GROSS_(IN_2022_DOLLARS)  6 non-null      int64
#  7   ARTIST                            6 non-null      str
#  8   TOUR_TITLE                        6 non-null      str
#  9   YEAR(S)                           6 non-null      str
#  10  SHOWS                             6 non-null      str
#  11  AVERAGE_GROSS                     6 non-null      int64
# dtypes: int64(8), str(4)
# ...

# %%
conn = sqlite3.connect('final_data.db')
df.to_sql('findal_artist_data',conn)
# Out:
# 6

# %%
cur = conn.cursor()

res = cur.execute("""SELECT * FROM findal_artist_data""")

res=res.fetchall()

print(res)
# Out:
# [(0, 0, 0, 1, 1, 2, 780000000, 780000000, 'TAYLOR SWIFT', 'THE ERAS TOUR †', '2023–2024', 'Intermediate', 13928571), (1, 1, 1, 2, 1, 7, 579800000, 579800000, 'BEYONCÉ', 'RENAISSANCE WORLD TOUR', '2023', 'Intermediate', 10353571), (2, 4, 4, 5, 2, 10, 345675146, 402844849, 'TAYLOR SWIFT', 'REPUTATION STADIUM TOUR', '2018', 'Intermediate', 6522173), (3, 2, 2, 3, 1, 2, 411000000, 560622615, 'MADONNA', 'STICKY & SWEET TOUR ‡[4][A]', '2008–2009', 'High', 4835294), (4, 5, 5, 6, 2, 10, 305158363, 388978496, 'MADONNA', 'THE MDNA TOUR', '2012', 'High', 3467709), (5, 3, 3, 4, 2, 10, 397300000, 454751555, 'PINK', 'BEAUTIFUL TRAUMA WORLD TOUR', '2018–2019', ' Extraorinary', 2546795)]

# %%
res = cur.execute("""
    SELECT *
    FROM findal_artist_data
    WHERE PEAK < 3
""")

print(res.fetchall())
# Out:
# [(0, 0, 0, 1, 1, 2, 780000000, 780000000, 'TAYLOR SWIFT', 'THE ERAS TOUR †', '2023–2024', 'Intermediate', 13928571), (1, 1, 1, 2, 1, 7, 579800000, 579800000, 'BEYONCÉ', 'RENAISSANCE WORLD TOUR', '2023', 'Intermediate', 10353571), (2, 4, 4, 5, 2, 10, 345675146, 402844849, 'TAYLOR SWIFT', 'REPUTATION STADIUM TOUR', '2018', 'Intermediate', 6522173), (3, 2, 2, 3, 1, 2, 411000000, 560622615, 'MADONNA', 'STICKY & SWEET TOUR ‡[4][A]', '2008–2009', 'High', 4835294), (4, 5, 5, 6, 2, 10, 305158363, 388978496, 'MADONNA', 'THE MDNA TOUR', '2012', 'High', 3467709), (5, 3, 3, 4, 2, 10, 397300000, 454751555, 'PINK', 'BEAUTIFUL TRAUMA WORLD TOUR', '2018–2019', ' Extraorinary', 2546795)]
