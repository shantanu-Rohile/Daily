# %%
import pandas as pd

# %%
df = pd.read_csv("my_file.csv")
df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5  2[4]           NaN  $345,675,146                     $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
# Data Inspection

print(df.shape)
df.info()
# Out:
# (20, 11)
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      str
#  2   All Time Peak                     6 non-null      str
#  3   Actual gross                      20 non-null     str
#  4   Adjusted gross (in 2022 dollars)  20 non-null     str
#  5   Artist                            20 non-null     str
#  6   Tour title                        20 non-null     str
#  7   Year(s)                           20 non-null     str
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     str
#  10  Ref.                              20 non-null     str
# dtypes: int64(2), str(9)
# memory usage: 3.4 KB

# %%
df.isnull().sum()
# Out:
# Rank                                 0
# Peak                                11
# All Time Peak                       14
# Actual gross                         0
# Adjusted gross (in 2022 dollars)     0
# Artist                               0
# Tour title                           0
# Year(s)                              0
# Shows                                0
# Average gross                        0
# Ref.                                 0
# dtype: int64

# %%
# clean column name

df.columns
# Out:
# Index(['Rank', 'Peak', 'All Time Peak', 'Actual gross',
#        'Adjusted gross (in 2022 dollars)', 'Artist', 'Tour title', 'Year(s)',
#        'Shows', 'Average gross', 'Ref.'],
#       dtype='str')

# %%
# clean the column name :

df.columns = df.columns.str.strip().str.upper().str.replace(" ","_")

# %%
df.head()
# Out:
#    RANK  PEAK ALL_TIME_PEAK  ACTUAL GROSS ADJUSTED GROSS_(IN_2022_DOLLARS)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5  2[4]           NaN  $345,675,146                     $402,844,849
#
#          ARTIST                   TOUR_TITLE    YEAR(S)  SHOWS AVERAGE_GROSS  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   REF.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
#Handle missing value names

df.columns
# Out:
# Index(['RANK', 'PEAK', 'ALL_TIME_PEAK', 'ACTUAL GROSS',
#        'ADJUSTED GROSS_(IN_2022_DOLLARS)', 'ARTIST', 'TOUR_TITLE', 'YEAR(S)',
#        'SHOWS', 'AVERAGE_GROSS', 'REF.'],
#       dtype='str')

# %%
df.bfill(inplace=True)
df.ffill(inplace=True)
# Out:
#     RANK   PEAK ALL_TIME_PEAK     ACTUAL GROSS  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]         10[9]     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]        14[17]     $280,000,000
# 7      7  1[20]        14[17]     $257,600,000
# 8      9  1[20]        14[17]     $256,084,556
# 9     10  1[20]        14[17]     $250,400,000
# 10    11  1[20]        14[17]  $229,100,000[b]
# 11    12  1[20]        14[17]     $227,400,000
# 12    13  1[20]        14[17]     $204,000,000
# 13    14  1[20]        14[17]     $200,000,000
# 14    15   2[c]        14[17]     $194,000,000
# 15    16   2[c]        14[17]     $184,000,000
# 16    17   2[c]        14[17]     $170,000,000
# 17    18   2[c]        14[17]     $169,800,000
# 18    19   2[c]        14[17]  $167,700,000[e]
# ...

# %%
df.isnull().sum()
# Out:
# RANK                                0
# PEAK                                0
# ALL_TIME_PEAK                       0
# ACTUAL GROSS                        0
# ADJUSTED GROSS_(IN_2022_DOLLARS)    0
# ARTIST                              0
# TOUR_TITLE                          0
# YEAR(S)                             0
# SHOWS                               0
# AVERAGE_GROSS                       0
# REF.                                0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
col_str=[]
all_col = df.columns
for i in all_col:
    print(i)
    if type(df.loc[0,i]) == type(" "):
        df[i] = df[i].str.strip().str.upper()
# Out:
# RANK
# PEAK
# ALL_TIME_PEAK
# ACTUAL GROSS
# ADJUSTED GROSS_(IN_2022_DOLLARS)
# ARTIST
# TOUR_TITLE
# YEAR(S)
# SHOWS
# AVERAGE_GROSS
# REF.

# %%
df.loc[0,"ARTIST"]
# Out:
# 'TAYLOR SWIFT'

# %%
df.head()
# Out:
#    RANK  PEAK ALL_TIME_PEAK  ACTUAL GROSS ADJUSTED GROSS_(IN_2022_DOLLARS)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5  2[4]         10[9]  $345,675,146                     $402,844,849
#
#          ARTIST                   TOUR_TITLE    YEAR(S)  SHOWS AVERAGE_GROSS  \
# 0  TAYLOR SWIFT              THE ERAS TOUR †  2023–2024     56   $13,928,571
# 1       BEYONCÉ       RENAISSANCE WORLD TOUR       2023     56   $10,353,571
# 2       MADONNA  STICKY & SWEET TOUR ‡[4][A]  2008–2009     85    $4,835,294
# 3          PINK  BEAUTIFUL TRAUMA WORLD TOUR  2018–2019    156    $2,546,795
# 4  TAYLOR SWIFT      REPUTATION STADIUM TOUR       2018     53    $6,522,173
#
#   REF.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
df.reset_index(drop=True)
# Out:
#     RANK   PEAK ALL_TIME_PEAK     ACTUAL GROSS  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]         10[9]     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]        14[17]     $280,000,000
# 7      7  1[20]        14[17]     $257,600,000
# 8      9  1[20]        14[17]     $256,084,556
# 9     10  1[20]        14[17]     $250,400,000
# 10    11  1[20]        14[17]  $229,100,000[B]
# 11    12  1[20]        14[17]     $227,400,000
# 12    13  1[20]        14[17]     $204,000,000
# 13    14  1[20]        14[17]     $200,000,000
# 14    15   2[C]        14[17]     $194,000,000
# 15    16   2[C]        14[17]     $184,000,000
# 16    17   2[C]        14[17]     $170,000,000
# 17    18   2[C]        14[17]     $169,800,000
# 18    19   2[C]        14[17]  $167,700,000[E]
# ...

# %%
#Validate

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   RANK                              20 non-null     int64
#  1   PEAK                              20 non-null     str
#  2   ALL_TIME_PEAK                     20 non-null     str
#  3   ACTUAL GROSS                      20 non-null     str
#  4   ADJUSTED GROSS_(IN_2022_DOLLARS)  20 non-null     str
#  5   ARTIST                            20 non-null     str
#  6   TOUR_TITLE                        20 non-null     str
#  7   YEAR(S)                           20 non-null     str
#  8   SHOWS                             20 non-null     int64
#  9   AVERAGE_GROSS                     20 non-null     str
#  10  REF.                              20 non-null     str
# dtypes: int64(2), str(9)
# memory usage: 3.6 KB

# %%
df.describe()
# Out:
#             RANK       SHOWS
# count  20.000000   20.000000
# mean   10.450000  110.000000
# std     5.942488   66.507617
# min     1.000000   41.000000
# 25%     5.750000   59.000000
# 50%    10.500000   87.000000
# 75%    15.250000  134.500000
# max    20.000000  325.000000

# %%
df.isnull().sum()
# Out:
# RANK                                0
# PEAK                                0
# ALL_TIME_PEAK                       0
# ACTUAL GROSS                        0
# ADJUSTED GROSS_(IN_2022_DOLLARS)    0
# ARTIST                              0
# TOUR_TITLE                          0
# YEAR(S)                             0
# SHOWS                               0
# AVERAGE_GROSS                       0
# REF.                                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import sqlite3

conn = sqlite3.connect("artist.db")

# %%
df = df.to_sql("artists",conn)

# %%
pd.read_sql_query("""SELECT * FROM artists""",conn)
# Out:
#     index  RANK   PEAK ALL_TIME_PEAK     ACTUAL GROSS  \
# 0       0     1      1             2     $780,000,000
# 1       1     2      1          7[2]     $579,800,000
# 2       2     3   1[4]          2[5]     $411,000,000
# 3       3     4   2[7]         10[7]     $397,300,000
# 4       4     5   2[4]         10[9]     $345,675,146
# 5       5     6   2[4]         10[9]     $305,158,363
# 6       6     7  2[10]        14[17]     $280,000,000
# 7       7     7  1[20]        14[17]     $257,600,000
# 8       8     9  1[20]        14[17]     $256,084,556
# 9       9    10  1[20]        14[17]     $250,400,000
# 10     10    11  1[20]        14[17]  $229,100,000[B]
# 11     11    12  1[20]        14[17]     $227,400,000
# 12     12    13  1[20]        14[17]     $204,000,000
# 13     13    14  1[20]        14[17]     $200,000,000
# 14     14    15   2[C]        14[17]     $194,000,000
# 15     15    16   2[C]        14[17]     $184,000,000
# ...

# %%
pd.read_sql_query("""SELECT * FROM artists where SHOWS>150""",conn)
# Out:
#    index  RANK   PEAK ALL_TIME_PEAK  ACTUAL GROSS  \
# 0      3     4   2[7]         10[7]  $397,300,000
# 1     11    12  1[20]        14[17]  $227,400,000
# 2     12    13  1[20]        14[17]  $204,000,000
# 3     13    14  1[20]        14[17]  $200,000,000
#
#   ADJUSTED GROSS_(IN_2022_DOLLARS)      ARTIST  \
# 0                     $454,751,555        PINK
# 1                     $295,301,479   LADY GAGA
# 2                     $251,856,802  KATY PERRY
# 3                     $299,676,265        CHER
#
#                                  TOUR_TITLE    YEAR(S)  SHOWS AVERAGE_GROSS  \
# 0               BEAUTIFUL TRAUMA WORLD TOUR  2018–2019    156    $2,546,795
# 1                   THE MONSTER BALL TOUR *  2009–2011    203    $1,118,227
# 2                      PRISMATIC WORLD TOUR  2014–2015    151    $1,350,993
# 3  LIVING PROOF: THE FAREWELL TOUR ‡[21][A]  2002–2005    325      $615,385
#
#    REF.
# 0   [7]
# 1  [18]
# 2  [19]
# 3  [20]
