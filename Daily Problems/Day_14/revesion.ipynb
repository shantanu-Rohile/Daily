# %%
# #organising the cleaning process 
# import pandas as pd
# #data loading
# df=pd.read_csv("Car_Data.csv")
# #data inspection
# #print(df.shape)
# #print(df.info())
# #print("null data:",df.isnull().sum())
# #print(df.head())
# #clean columnname
# #df.columns=(df.columns.str.strip().str.title().str.replace(" ","_"))
# print(df.columns)
# #handling missing values
# #df=df.replace(["NA","N/A","?","-","null","NULL"],pd.NA)
# #remove duplicates
# #df=df.drop_duplicates()
# #print(df)
# #cleaning string
# textcol=["Brand","Color"]
# for col in textcol:
#   df[col]=(df[col].str.strip().str.upper())
# print(df)
# #fill missing values
# num_col = ["Year", "Mileage", "Price"]
# for i in num_col:
#     df[i] = df[i].fillna(df[i].mean())
# df["Brand"]=df["Brand"].fillna("unknown")
# #handling invalid price
# df.loc[df["Price"]<0,"Price"]=0
# #convert the datatype of the column
# df['Price']=pd.to_numeric(df['Price'],errors='coerce')
# df['Price']=df['Price'].astype('int64')
# print(df.head())
# #reset index
# df=df.reset_index(drop=True)
# #validate
# print(df.info())
# print(df.describe()) 
# print(df.isnull.sum())
# print(df.head())

# %%
import pandas as pd

# %%
df = pd.read_csv("laptop_battery_health_usage_updated2.csv")

# %%
print(df)
# Out:
#    device_id   brand  model_year       os   usage_type  daily_usage_hours  \
# 0      LB001      HP      2021.0  Windows       Office                  6
# 1      LB002    Dell         NaN  Windows          NaN                  8
# 2      LB003   Apple      2022.0    macOS     Creative                  7
# 3      LB004  Lenovo      2019.0  Windows      Student                  5
# 4      LB005    Asus      2021.0  Windows       Gaming                  9
# 5        NaN    Acer      2020.0      NaN       Office                  6
# 6      LB004  Lenovo      2019.0  Windows      Student                  5
# 7      LB005    Asus      2021.0  Windows       Gaming                  9
# 8        NaN    Acer      2020.0      NaN       Office                  6
# 9      LB007   Apple      2023.0    macOS  Programming                  8
# 10     LB008      HP      2018.0  Windows      Student                  4
# 11     LB009    Dell      2022.0  Windows       Office                  6
# ...

# %%
# Inspecting the data

df.info()
df.describe()

df.isnull().sum()

df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   device_id                 55 non-null     str
#  1   brand                     54 non-null     str
#  2   model_year                55 non-null     float64
#  3   os                        52 non-null     str
#  4   usage_type                45 non-null     str
#  5   daily_usage_hours         60 non-null     int64
#  6   charging_cycles           48 non-null     float64
#  7   avg_charge_limit_percent  56 non-null     float64
#  8   battery_health_percent    54 non-null     float64
#  9   battery_age_months        60 non-null     int64
#  10  overheating_issues        55 non-null     str
#  11  performance_rating        60 non-null     int64
# dtypes: float64(4), int64(3), str(5)
# memory usage: 7.1 KB
# ...

# %%
df.columns = df.columns.str.strip().str.upper().str.replace(" ","_")

# %%
all_col=df.columns

df.columns
# Out:
# Index(['DEVICE_ID', 'BRAND', 'MODEL_YEAR', 'OS', 'USAGE_TYPE',
#        'DAILY_USAGE_HOURS', 'CHARGING_CYCLES', 'AVG_CHARGE_LIMIT_PERCENT',
#        'BATTERY_HEALTH_PERCENT', 'BATTERY_AGE_MONTHS', 'OVERHEATING_ISSUES',
#        'PERFORMANCE_RATING'],
#       dtype='str')

# %%
str_col = []

for i in all_col:
    if type((df[i][0])) == type(""):
        str_col.append(i)

# %%
print(str_col)
# Out:
# ['DEVICE_ID', 'BRAND', 'OS', 'USAGE_TYPE', 'OVERHEATING_ISSUES']

# %%
for i in str_col:
    df[i] = (df[i].str.strip().str.upper())

# %%
for i in str_col:
    df[i] = df[i].replace(["NA","N/A","NaN","Unkown","unknown","NULL","null"],pd.NA)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
num_col = []

for i in all_col:
    if i not in str_col:
        num_col.append(i)

# %%
print(num_col)
# Out:
# ['MODEL_YEAR', 'DAILY_USAGE_HOURS', 'CHARGING_CYCLES', 'AVG_CHARGE_LIMIT_PERCENT', 'BATTERY_HEALTH_PERCENT', 'BATTERY_AGE_MONTHS', 'PERFORMANCE_RATING']

# %%
df.head()
# Out:
#   DEVICE_ID   BRAND  MODEL_YEAR       OS USAGE_TYPE  DAILY_USAGE_HOURS  \
# 0     LB001      HP      2021.0  WINDOWS     OFFICE                  6
# 1     LB002    DELL         NaN  WINDOWS        NaN                  8
# 2     LB003   APPLE      2022.0    MACOS   CREATIVE                  7
# 3     LB004  LENOVO      2019.0  WINDOWS    STUDENT                  5
# 4     LB005    ASUS      2021.0  WINDOWS     GAMING                  9
#
#    CHARGING_CYCLES  AVG_CHARGE_LIMIT_PERCENT  BATTERY_HEALTH_PERCENT  \
# 0            420.0                      90.0                    86.0
# 1            610.0                     100.0                    78.0
# 2            310.0                      85.0                    92.0
# 3            700.0                     100.0                     NaN
# 4            820.0                     100.0                    65.0
#
#    BATTERY_AGE_MONTHS OVERHEATING_ISSUES  PERFORMANCE_RATING
# 0                  36                 NO                   4
# ...

# %%
for i in num_col:
    df[i] = df[i].fillna(df[i].mean())

# %%
for i in num_col:
    print(df[i].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
for i in str_col:
    df[i] = df[i].fillna('unknown')

# %%
for i in str_col:
    print(df[i].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
for i in num_col:
   print( (df[i] < 0).sum().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
for i in num_col:
    df[i]= pd.to_numeric(df[i],errors='coerce')
    df[i] = df[i].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 50 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DEVICE_ID                 50 non-null     str
#  1   BRAND                     50 non-null     str
#  2   MODEL_YEAR                50 non-null     int64
#  3   OS                        50 non-null     str
#  4   USAGE_TYPE                50 non-null     str
#  5   DAILY_USAGE_HOURS         50 non-null     int64
#  6   CHARGING_CYCLES           50 non-null     int64
#  7   AVG_CHARGE_LIMIT_PERCENT  50 non-null     int64
#  8   BATTERY_HEALTH_PERCENT    50 non-null     int64
#  9   BATTERY_AGE_MONTHS        50 non-null     int64
#  10  OVERHEATING_ISSUES        50 non-null     str
#  11  PERFORMANCE_RATING        50 non-null     int64
# dtypes: int64(7), str(5)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#         MODEL_YEAR  DAILY_USAGE_HOURS  CHARGING_CYCLES  \
# count    50.000000          50.000000        50.000000
# mean   2020.560000           6.600000       532.000000
# std       1.500476           1.498298       192.058665
# min    2018.000000           4.000000       180.000000
# 25%    2020.000000           6.000000       412.500000
# 50%    2020.500000           6.000000       532.000000
# 75%    2022.000000           8.000000       635.000000
# max    2023.000000          10.000000       950.000000
#
#        AVG_CHARGE_LIMIT_PERCENT  BATTERY_HEALTH_PERCENT  BATTERY_AGE_MONTHS  \
# count                 50.000000               50.000000           50.000000
# mean                  92.360000               79.860000           42.240000
# std                    6.681562               11.552913           18.118161
# min                   80.000000               55.000000           12.000000
# 25%                   90.000000               74.000000           25.500000
# ...

# %%
df.isnull().sum()
# Out:
# DEVICE_ID                   0
# BRAND                       0
# MODEL_YEAR                  0
# OS                          0
# USAGE_TYPE                  0
# DAILY_USAGE_HOURS           0
# CHARGING_CYCLES             0
# AVG_CHARGE_LIMIT_PERCENT    0
# BATTERY_HEALTH_PERCENT      0
# BATTERY_AGE_MONTHS          0
# OVERHEATING_ISSUES          0
# PERFORMANCE_RATING          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
